# %%
import pandas as pd
import geojson
import json

# %%
#Moving directory

cd Desktop\Janae
# Out:
# [WinError 3] The system cannot find the path specified: 'Desktop\\Janae'
# C:\Users\raksh\Desktop\Janae

# %%
#Lists all files in directory

ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D420-47A7
#
#  Directory of C:\Users\raksh\Desktop\Janae
#
# 22/06/2022  21:23    <DIR>          .
# 06/06/2022  15:09    <DIR>          ..
# 22/06/2022  21:10    <DIR>          .ipynb_checkpoints
# 15/05/2022  09:11           257,380 california-counties.geojson
# 20/03/2022  10:17            13,050 Crime_Statistics_Janae.xlsx
# 22/06/2022  21:00         3,522,010 crimes_data_final.csv
# 15/05/2022  09:49         5,573,348 Crimes_data-v1.csv
# 20/03/2022  10:10           282,376 Dataframes_and_Lambda_functions_tXC0wIP.ipynb
# 15/05/2022  09:53       265,746,743 Final_merged_data
# 22/06/2022  21:21        20,017,481 Final_merged_data.csv
# 22/06/2022  21:23           163,525 Geoplots.ipynb
# 15/05/2022  09:11         5,365,441 la-zip-code-areas-2012.geojson
# 23/03/2022  12:50            84,691 nyc-park-crime-stats-q4-2015.xlsx
# 22/06/2022  21:22            10,153 Plot generation.ipynb
# ...

# %%
data = pd.read_json('california-counties.geojson')

# %%
data
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Al...
# 1   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Al...
# 2   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Am...
# 3   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Bu...
# 4   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Ca...
# 5   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Co...
# 6   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Co...
# 7   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'De...
# 8   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Tu...
# 9   FeatureCollection  {'type': 'Feature', 'properties': {'name': 'El...
# 10  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Fr...
# 11  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Gl...
# ...

# %%
#Print first row and second column
data['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'name': 'Alameda',
#   'cartodb_id': 1,
#   'created_at': '2015-07-04T21:04:58Z',
#   'updated_at': '2015-07-04T21:04:58Z'},
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[-122.312934, 37.897333],
#      [-122.28848, 37.897925],
#      [-122.27418, 37.905025],
#      [-122.263946, 37.903734],
#      [-122.249477, 37.893086],
#      [-122.248914, 37.886867],
#      [-122.223878, 37.878326],
#      [-122.216276, 37.868822],
#      [-122.220389, 37.864427],
#      [-122.204094, 37.851387],
#      [-122.196101, 37.842005],
#      [-122.184177, 37.833926],
#      [-122.185977, 37.820726],
#      [-122.166873, 37.813424],
#      [-122.157392, 37.817952],
#      [-122.148808, 37.81376],
#      [-122.140551, 37.804594],
#      [-122.045473, 37.798126],
#      [-122.030472, 37.787727],
#      [-122.014072, 37.780227],
#      [-121.997771, 37.763227],
#      [-122.010771, 37.755127],
#      [-122.011771, 37.747428],
# ...

# %%
data = data.drop(columns = ['type'])
data
# Out:
#                                              features
# 0   {'type': 'Feature', 'properties': {'name': 'Al...
# 1   {'type': 'Feature', 'properties': {'name': 'Al...
# 2   {'type': 'Feature', 'properties': {'name': 'Am...
# 3   {'type': 'Feature', 'properties': {'name': 'Bu...
# 4   {'type': 'Feature', 'properties': {'name': 'Ca...
# 5   {'type': 'Feature', 'properties': {'name': 'Co...
# 6   {'type': 'Feature', 'properties': {'name': 'Co...
# 7   {'type': 'Feature', 'properties': {'name': 'De...
# 8   {'type': 'Feature', 'properties': {'name': 'Tu...
# 9   {'type': 'Feature', 'properties': {'name': 'El...
# 10  {'type': 'Feature', 'properties': {'name': 'Fr...
# 11  {'type': 'Feature', 'properties': {'name': 'Gl...
# 12  {'type': 'Feature', 'properties': {'name': 'Hu...
# 13  {'type': 'Feature', 'properties': {'name': 'In...
# 14  {'type': 'Feature', 'properties': {'name': 'La...
# 15  {'type': 'Feature', 'properties': {'name': 'Sa...
# ...

# %%
data['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'name': 'Alameda',
#   'cartodb_id': 1,
#   'created_at': '2015-07-04T21:04:58Z',
#   'updated_at': '2015-07-04T21:04:58Z'},
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[-122.312934, 37.897333],
#      [-122.28848, 37.897925],
#      [-122.27418, 37.905025],
#      [-122.263946, 37.903734],
#      [-122.249477, 37.893086],
#      [-122.248914, 37.886867],
#      [-122.223878, 37.878326],
#      [-122.216276, 37.868822],
#      [-122.220389, 37.864427],
#      [-122.204094, 37.851387],
#      [-122.196101, 37.842005],
#      [-122.184177, 37.833926],
#      [-122.185977, 37.820726],
#      [-122.166873, 37.813424],
#      [-122.157392, 37.817952],
#      [-122.148808, 37.81376],
#      [-122.140551, 37.804594],
#      [-122.045473, 37.798126],
#      [-122.030472, 37.787727],
#      [-122.014072, 37.780227],
#      [-121.997771, 37.763227],
#      [-122.010771, 37.755127],
#      [-122.011771, 37.747428],
# ...

# %%
data['coordinates'] = data['features'].apply(lambda x: x['geometry']['coordinates'])
data
# Out:
#                                              features  \
# 0   {'type': 'Feature', 'properties': {'name': 'Al...
# 1   {'type': 'Feature', 'properties': {'name': 'Al...
# 2   {'type': 'Feature', 'properties': {'name': 'Am...
# 3   {'type': 'Feature', 'properties': {'name': 'Bu...
# 4   {'type': 'Feature', 'properties': {'name': 'Ca...
# 5   {'type': 'Feature', 'properties': {'name': 'Co...
# 6   {'type': 'Feature', 'properties': {'name': 'Co...
# 7   {'type': 'Feature', 'properties': {'name': 'De...
# 8   {'type': 'Feature', 'properties': {'name': 'Tu...
# 9   {'type': 'Feature', 'properties': {'name': 'El...
# 10  {'type': 'Feature', 'properties': {'name': 'Fr...
# 11  {'type': 'Feature', 'properties': {'name': 'Gl...
# 12  {'type': 'Feature', 'properties': {'name': 'Hu...
# 13  {'type': 'Feature', 'properties': {'name': 'In...
# 14  {'type': 'Feature', 'properties': {'name': 'La...
# 15  {'type': 'Feature', 'properties': {'name': 'Sa...
# ...

# %%
data['name'] = data['features'].apply(lambda x: x['properties']['name'])
data
# Out:
#                                              features  \
# 0   {'type': 'Feature', 'properties': {'name': 'Al...
# 1   {'type': 'Feature', 'properties': {'name': 'Al...
# 2   {'type': 'Feature', 'properties': {'name': 'Am...
# 3   {'type': 'Feature', 'properties': {'name': 'Bu...
# 4   {'type': 'Feature', 'properties': {'name': 'Ca...
# 5   {'type': 'Feature', 'properties': {'name': 'Co...
# 6   {'type': 'Feature', 'properties': {'name': 'Co...
# 7   {'type': 'Feature', 'properties': {'name': 'De...
# 8   {'type': 'Feature', 'properties': {'name': 'Tu...
# 9   {'type': 'Feature', 'properties': {'name': 'El...
# 10  {'type': 'Feature', 'properties': {'name': 'Fr...
# 11  {'type': 'Feature', 'properties': {'name': 'Gl...
# 12  {'type': 'Feature', 'properties': {'name': 'Hu...
# 13  {'type': 'Feature', 'properties': {'name': 'In...
# 14  {'type': 'Feature', 'properties': {'name': 'La...
# 15  {'type': 'Feature', 'properties': {'name': 'Sa...
# ...

# %%
df = pd.read_csv('Crimes_data_final.csv')
df
# Out:
#        Year          County                          NCICCode  Homicide_sum  \
# 0      1985  Alameda County  Alameda Co. Sheriff's Department             3
# 1      1985  Alameda County                           Alameda             7
# 2      1985  Alameda County                            Albany             1
# 3      1985  Alameda County                          Berkeley            11
# 4      1985  Alameda County                        Emeryville             0
# ...     ...             ...                               ...           ...
# 26404  2020     Yuba County     Yuba Co. Sheriff's Department             2
# 26405  2020     Yuba County                        Marysville             0
# 26406  2020     Yuba County                         Wheatland             0
# 26407  2020     Yuba County           Union Pacific RR - Yuba             0
# 26408  2020     Yuba County          CA Highway Patrol - Yuba             0
#
# ...

# %%
df['name'] = df['County'].apply(lambda x: x[:-7])
df
# Out:
#        Year          County                          NCICCode  Homicide_sum  \
# 0      1985  Alameda County  Alameda Co. Sheriff's Department             3
# 1      1985  Alameda County                           Alameda             7
# 2      1985  Alameda County                            Albany             1
# 3      1985  Alameda County                          Berkeley            11
# 4      1985  Alameda County                        Emeryville             0
# ...     ...             ...                               ...           ...
# 26404  2020     Yuba County     Yuba Co. Sheriff's Department             2
# 26405  2020     Yuba County                        Marysville             0
# 26406  2020     Yuba County                         Wheatland             0
# 26407  2020     Yuba County           Union Pacific RR - Yuba             0
# 26408  2020     Yuba County          CA Highway Patrol - Yuba             0
#
# ...

# %%
df['name'].value_counts()
# Out:
# Los Angeles        3675
# Orange             1456
# San Bernardino     1118
# Riverside          1111
# Contra Costa        940
# San Diego           884
# Santa Clara         868
# Alameda             848
# San Mateo           846
# Fresno              715
# Monterey            646
# Ventura             632
# Sonoma              609
# Sacramento          545
# Kern                540
# San Luis Obispo     540
# Marin               531
# Stanislaus          500
# Santa Barbara       464
# Tulare              438
# Siskiyou            435
# Humboldt            409
# San Joaquin         400
# Merced              400
# Solano              388
# Butte               383
# Imperial            356
# Santa Cruz          345
# Napa                316
# Yolo                304
# Placer              300
# Kings               298
# San Francisco       269
# Mendocino           240
# Amador              217
# Shasta              210
# Nevada              207
# San Benito          195
# ...

# %%
final = df.merge(data, on = 'name')
final
# Out:
#        Year          County                          NCICCode  Homicide_sum  \
# 0      1985  Alameda County  Alameda Co. Sheriff's Department             3
# 1      1985  Alameda County                           Alameda             7
# 2      1985  Alameda County                            Albany             1
# 3      1985  Alameda County                          Berkeley            11
# 4      1985  Alameda County                        Emeryville             0
# ...     ...             ...                               ...           ...
# 26404  2020     Yuba County     Yuba Co. Sheriff's Department             2
# 26405  2020     Yuba County                        Marysville             0
# 26406  2020     Yuba County                         Wheatland             0
# 26407  2020     Yuba County           Union Pacific RR - Yuba             0
# 26408  2020     Yuba County          CA Highway Patrol - Yuba             0
#
# ...

# %%
final.to_csv('Final_merged_data.csv')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D420-47A7
#
#  Directory of C:\Users\raksh\Desktop\Janae
#
# 22/06/2022  21:26    <DIR>          .
# 06/06/2022  15:09    <DIR>          ..
# 22/06/2022  21:10    <DIR>          .ipynb_checkpoints
# 15/05/2022  09:11           257,380 california-counties.geojson
# 20/03/2022  10:17            13,050 Crime_Statistics_Janae.xlsx
# 22/06/2022  21:00         3,522,010 crimes_data_final.csv
# 15/05/2022  09:49         5,573,348 Crimes_data-v1.csv
# 20/03/2022  10:10           282,376 Dataframes_and_Lambda_functions_tXC0wIP.ipynb
# 15/05/2022  09:53       265,746,743 Final_merged_data
# 22/06/2022  21:26       263,695,405 Final_merged_data.csv
# 22/06/2022  21:23           163,525 Geoplots.ipynb
# 15/05/2022  09:11         5,365,441 la-zip-code-areas-2012.geojson
# 23/03/2022  12:50            84,691 nyc-park-crime-stats-q4-2015.xlsx
# 22/06/2022  21:26            28,942 Plot generation.ipynb
# ...
